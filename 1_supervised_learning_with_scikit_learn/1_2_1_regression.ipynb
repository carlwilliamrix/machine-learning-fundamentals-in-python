# %% [markdown]
# # Regression

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

# %%
diabetes_df = pd.read_csv('../resources/diabetes_clean.csv')
print(diabetes_df.head())
# Out:
#    pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 0            6      148         72       35        0  33.6  0.627   50
# 1            1       85         66       29        0  26.6  0.351   31
# 2            8      183         64        0        0  23.3  0.672   32
# 3            1       89         66       23       94  28.1  0.167   21
# 4            0      137         40       35      168  43.1  2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %% [markdown]
# # Predicting Blood Glucose Level
# features: pregnancies, tricpes, insulin levels, bmi, age in years and diabetes status (1 indicating diagnosis and zero absence of diagnosis)

# %%
# Creating feature and target arrays
X = diabetes_df.drop(columns='glucose', axis=1).values
y = diabetes_df['glucose'].values

# Making predictions from a single feature
# Slice out BMI column of X
X_bmi = X[:, 3]
print(y.shape, X_bmi.shape)
# Out:
# (768,) (768,)

# %%
# Must be formatted as two-dimensional array to be accepted by scitkit-learn
X_bmi = X_bmi.reshape(-1, 1)
print(X_bmi.shape)
# Out:
# (768, 1)

# %%
# Plotting glucose vs. body mass index
import matplotlib.pyplot as plt
plt.scatter(X_bmi, y)
plt.ylabel("Blood Glucose (mg/dl)")
plt.xlabel("Body Mass Index")
plt.xlim(0, 60)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_bmi, y)
predictions = reg.predict(X_bmi)
plt.scatter(X_bmi, y)
plt.plot(X_bmi, predictions)
plt.ylabel("Blood Glucose (mg/dl)")
plt.xlabel("Body Mass Index")
plt.show()
